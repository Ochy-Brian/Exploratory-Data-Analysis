# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
#read the csv file
data=pd.read_csv('/content/supermarket_sales - Sheet1.csv')
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#display the top 5 rows in the dataset
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#display last 5 rows of the dataset so as to also get to know how many rows are in the dataset
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
#print random 5 rows from our dataset
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 284  565-17-3836      A     Yangon        Member  Female    Health and beauty
# 823  276-75-6884      A     Yangon        Normal  Female    Health and beauty
# 404  587-03-7455      C  Naypyitaw        Member  Female  Fashion accessories
# 923  887-42-0517      C  Naypyitaw        Normal  Female    Sports and travel
# 628  856-66-2701      A     Yangon        Member    Male   Home and lifestyle
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 284       47.67         4   9.5340  200.2140  3/12/2019  14:21         Cash
# 823       68.71         3  10.3065  216.4365   3/4/2019  10:05         Cash
# 404       97.79         7  34.2265  718.7565  2/16/2019  17:30      Ewallet
# 923       83.14         7  29.0990  611.0790  1/10/2019  10:31  Credit card
# 628       53.30         3   7.9950  167.8950  1/25/2019  14:19      Ewallet
#
# ...

# %%
#find the shape of our dataset(number of rows and number of columns)
data.shape
# Out:
# (1000, 17)

# %%
print('Number of Columns', data.shape[0])
print('Number of Rows', data.shape[1])
# Out:
# Number of Columns 1000
# Number of Rows 17

# %%
#check for null values in the dataset
data.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#get information about our dataset like total number of rows,total number of columns,datatypes of each column and memory requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#get overall statistics summarry about the dataset
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %% [markdown]
# #Univariate analysis

# %%
#find numerical and categorical columns first
cat=[]
num=[]
for column in data.columns:
  if data[column].nunique() > 10:
    num.append(column)
  else:
    cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
#find aggregate sales among branches(categorical column)
sns.countplot(data['Branch'])
# Out:
# <Axes: xlabel='count', ylabel='Branch'>

# %%
data['Branch'].value_counts().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: ylabel='Branch'>

# %%
#find the most popular payment method used by customers(categorical column)
data['Payment'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
#find the distribution of customer ratings(Numerical column)
#plot used to check skewness and distribution of our data
sns.distplot(data['Rating'])
# Out:
# <ipython-input-17-5a57f2aa8d4e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Rating'])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#finding the distribution of cost of goods sold(Numerical column)
sns.distplot(data['cogs'])
# Out:
# <ipython-input-19-a803efd828ca>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['cogs'])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
#find the skewness value of cogs
#if skewness value is positive means data is right skewed
#if skewness value is negative means data is left skewed
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
#finding the distribution of cost of goods sold(Numerical column)
sns.boxplot(data['cogs'])
# Out:
# <Axes: ylabel='cogs'>

# %% [markdown]
# #BIVARIATE AND MULTIVARIATE ANALYSIS

# %%
#bivariate analysis is taking two vatiables at a time and perform analysis to determine the relationships between them
#multivariate analysis is taking more  than two variables at a time and perform analysis to determine the relationships between them

#does the cost of goods sold affect the ratings that customers provide(Numerical-Numerical)

# %%
#confirm the numerical and categorical columns
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(x=data['cogs'],y=data['Rating'])
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
#does gross income affect the ratings that the customers provide?(Numerical-Numerical)
sns.scatterplot(x=data['gross income'],y=data['Rating'])
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
#find the most profitable branch as per gross income(Numerical-Categorical)
sns.barplot(x='Branch',y='gross income', data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#how to perform multivariate analysis,
#dataset consist of branches from 3 cities
sns.barplot(x='Branch',y='gross income', data=data, hue=data['City'])
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#Is there any relationship between gender and gross income?numerical-categorical
#bivariate analysis
sns.boxplot(x=data['Gender'], y=data['gross income'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>
# <Axes: xlabel='Gender', ylabel='gross income'>
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
#multivariate analysis
sns.boxplot(x=data['Gender'], y=data['gross income'], hue=data['Customer type'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
#find the product line that generates the most income(numerical-categorical)
#fiirst display column names
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(x= data['Product line'],y=data['gross income'])
plt.xticks(rotation=80)
plt.show()

# %%
#find the highest unit price in the product line
sns.barplot(x= data['Product line'],y=data['Unit price'])
plt.xticks(rotation=80)
plt.show()

# %%
#Find different payment methods used by customers citywise using crosstab
pd.crosstab(data['City'],data['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
#which productline is purchased in the highest quantity?
data.groupby('Product line').sum()['Quantity'].plot(kind='bar')
# Out:
# <ipython-input-54-f496c509b9d9>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Product line').sum()['Quantity'].plot(kind='bar')
# <Axes: xlabel='Product line'>

# %%
#display daily sales by day of the week
#display columns first
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')
